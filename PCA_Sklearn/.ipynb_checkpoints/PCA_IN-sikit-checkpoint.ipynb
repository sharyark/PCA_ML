# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score
import numpy as np

# %%
df = pd.read_csv('mushrooms.csv')

# %%
# df.sample(10)
# df['class'].unique()

# %%
# df = pd.get_dummies(df)
X = df.iloc[:,1:]
Y = df.iloc[:,0]
X = pd.get_dummies(X)
X.head()
# Out:
#    cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2         True        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 0         True          False          False           True          False
# 1         True          False          False           True          False
# 2        False          False          False           True          False
# 3         True          False          False          False           True
# 4         True          False          False           True          False
#
#    ...  population_s  population_v  population_y  habitat_d  habitat_g  \
# 0  ...          True         False         False      False      False
# 1  ...         False         False         False      False       True
# 2  ...         False         False         False      False      False
# 3  ...          True         False         False      False      False
# 4  ...         False         False         False      False       True
#
#    habitat_l  habitat_m  habitat_p  habitat_u  habitat_w
# 0      False      False      False       True      False
# 1      False      False      False      False      False
# 2      False       True      False      False      False
# 3      False      False      False       True      False
# 4      False      False      False      False      False
#
# [5 rows x 117 columns]

# %%
Y.head()
# Out:
# 0    p
# 1    e
# 2    e
# 3    p
# 4    e
# Name: class, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)
X_train.head()
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 3887        False        False        False        False        False
# 4119        False        False         True        False        False
# 1600        False        False        False        False        False
# 4988        False        False        False        False        False
# 6757        False        False         True        False        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 3887         True          False          False           True          False
# 4119        False           True          False          False          False
# 1600         True          False          False          False           True
# 4988         True          False          False          False           True
# 6757        False          False          False          False           True
#
#       ...  population_s  population_v  population_y  habitat_d  habitat_g  \
# 3887  ...          True         False         False       True      False
# 4119  ...         False          True         False      False       True
# 1600  ...         False         False          True       True      False
# 4988  ...         False         False          True      False      False
# 6757  ...         False          True         False       True      False
#
#       habitat_l  habitat_m  habitat_p  habitat_u  habitat_w
# 3887      False      False      False      False      False
# 4119      False      False      False      False      False
# 1600      False      False      False      False      False
# 4988      False      False       True      False      False
# 6757      False      False      False      False      False
#
# [5 rows x 117 columns]

# %%
# first step is standardize your data before applying pca
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(X_train)
x_test = scaler.transform(X_test)

# %%
y_train.unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# Mpdel without PCA

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# y_test
# Out:
# array(['e', 'p', 'p', ..., 'e', 'e', 'p'], dtype=object)

# %%
precision = precision_score(y_test, y_pred, pos_label='p')
print("Precision:", precision)
# Out:
# Precision: 1.0

# %%
y_pred
# Out:
# array(['e', 'p', 'p', ..., 'e', 'e', 'p'], dtype=object)

# %%
# False in (np.array(y_pred) == np.array(y_test))
# Out:
# False
